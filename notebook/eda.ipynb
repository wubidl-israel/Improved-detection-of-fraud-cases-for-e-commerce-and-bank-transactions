# %%
import os, sys
import pandas as pd
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
print(parent_dir)
sys.path.insert(0, parent_dir)
from scripts.preprocess import cleaning
from scripts.eda import EDA
# Out:
# /Users/amantebeje/Desktop/projects/Fraud-detection

# %%
credit='/Users/amantebeje/Desktop/projects/FRAUD-DETECTION/Data/creditcard.csv'
fraud='/Users/amantebeje/Desktop/projects/FRAUD-DETECTION/Data/Fraud_Data.csv'
ip='/Users/amantebeje/Desktop/projects/FRAUD-DETECTION/Data/IpAddress_to_Country.csv'
c,f,i=cleaning.load_data(credit,fraud,ip)
c
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
f
# Out:
#         user_id          signup_time        purchase_time  purchase_value  \
# 0         22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1        333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2          1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3        150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4        221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
# ...         ...                  ...                  ...             ...
# 151107   345170  2015-01-27 03:03:34  2015-03-29 00:30:47              43
# 151108   274471  2015-05-15 17:43:29  2015-05-26 12:24:39              35
# 151109   368416  2015-03-03 23:07:31  2015-05-20 07:07:47              40
# 151110   207709  2015-07-09 20:06:07  2015-09-07 09:34:46              46
# 151111   138208  2015-06-10 07:02:20  2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class
# ...

# %%
i
# Out:
#         lower_bound_ip_address  upper_bound_ip_address    country
# 0                 1.677722e+07                16777471  Australia
# 1                 1.677747e+07                16777727      China
# 2                 1.677773e+07                16778239      China
# 3                 1.677824e+07                16779263  Australia
# 4                 1.677926e+07                16781311      China
# ...                        ...                     ...        ...
# 138841            3.758092e+09              3758093311  Hong Kong
# 138842            3.758093e+09              3758094335      India
# 138843            3.758095e+09              3758095871      China
# 138844            3.758096e+09              3758096127  Singapore
# 138845            3.758096e+09              3758096383  Australia
#
# [138846 rows x 3 columns]

# %%
cleaning.dtype(c,f,i)
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object
# user_id             int64
# signup_time        object
# purchase_time      object
# purchase_value      int64
# device_id          object
# source             object
# browser            object
# sex                object
# age                 int64
# ip_address        float64
# class               int64
# dtype: object
# lower_bound_ip_address    float64
# ...

# %%
c_edited=cleaning.check_dup(c,f,i)
# Out:
# 1081
# 0
# 0

# %%
merged_data=cleaning.merge(f,i)
merged_data
# Out:
#         user_id          signup_time        purchase_time  purchase_value  \
# 0         22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1        333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2          1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3        221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
# 4        159135  2015-05-21 06:03:03  2015-07-09 08:05:14              42
# ...         ...                  ...                  ...             ...
# 129141   360761  2015-02-10 06:39:44  2015-06-03 08:18:30              13
# 129142   345170  2015-01-27 03:03:34  2015-03-29 00:30:47              43
# 129143   274471  2015-05-15 17:43:29  2015-05-26 12:24:39              35
# 129144   368416  2015-03-03 23:07:31  2015-05-20 07:07:47              40
# 129145   207709  2015-07-09 20:06:07  2015-09-07 09:34:46              46
#
#             device_id source browser sex  age  ip_address  class  \
# ...

# %%
EDA.detect_outliers_with_boxplot(merged_data,'purchase_value')

# %%
EDA.numerical_univariate(merged_data,'purchase_value')

# %%
EDA.categorical_univariate(merged_data,'browser')

# %%
EDA.browser(merged_data,'source')

# %%
EDA.age_group(merged_data)
# Out:
# /Users/amantebeje/Desktop/projects/Fraud-detection/scripts/eda.py:56: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   class_1_age_group_counts = class_1.groupby('age_group').size().reset_index(name='count')
